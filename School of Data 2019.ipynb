# %% [markdown]
# # Databases, Dashboards, and Death to Paper: Part 1
#
# What we're going to accomplish:
#
# 1. **Extract** data from our asset management system
# 2. **Transform** the data to make it comatible with our open data portal
# 3. **Load** the data into our open data portal
#
# ...with Python!

# %% [markdown]
# ## Extract Some Data
#
# We're going to download traffic signal data from our asset management system.
#
# [Click here](https://atd.knack.com/test#signal-requests/signal-request-details/5bbd028a4c1e902ee11110a3/) to visit a (fake) Traffic Signal Request in our assset management system.
#
# ![alt text](./img/sig_req.png "Logo Title Text 1")

# %%
from pprint import pprint as print # pretty printing
import knackpy # knack API client


auth = {
    "app_id" : "5bbcfd7b4ae801302fe650c3",
    "api_key" : "f9debcb0-d0cc-11e8-b6a3-6727e456c7fb"
}

# get data
kn = knackpy.Knack(
    scene="scene_514",
    view="view_2571",
    ref_obj=["object_171"],
    app_id=auth["app_id"],
    api_key=auth["api_key"]
)
# Out:
# Get data from https://api.knack.com/v1/pages/scene_514/views/view_2571/records?rows_per_page=1000
# Retrieved 1325 records
# Get field data for object_171
# Get data from https://api.knack.com/v1/objects/object_171/fields?rows_per_page=1000
# Retrieved 18 fields

# %%
print(kn.data[0:1])
# Out:
# [{'ATD_EVAL_ID': 'TVL19-005420',
#   'CROSS_ST': ' CUTTING HORSE LN',
#   'CROSS_ST_BLOCK': 1601,
#   'EVAL_RANK': 203,
#   'EVAL_SCORE': '0',
#   'EVAL_STATUS': 'IN PROGRESS',
#   'EVAL_TYPE': 'TRAFFIC',
#   'FUNDING_STATUS': 'None Identified',
#   'LANDMARK': '',
#   'LOCATION_LATITUDE': 30.417382,
#   'LOCATION_LONGITUDE': -97.684626,
#   'LOCATION_NAME': ' METRIC BLVD / CUTTING HORSE LN',
#   'PRIMARY_ST': ' METRIC BLVD',
#   'PRIMARY_ST_BLOCK': 12801,
#   'RANK_ROUND_MO': 'DEC',
#   'RANK_ROUND_YR': '2018',
#   'REQUEST_ID': 'REQ19-003505',
#   'REQUEST_STATUS': 'RECENTLY RECEIVED',
#   'id': '5c534c420fd877638727456a'}]

# %% [markdown]
# # Transform
#
# 1. Change column names to lower case
#
# 2. Drop "id" column

# %%
data_lower_case = [{key.lower(): value for key, value in record.items()} for record in kn.data]

print(data_lower_case[0:1])
# Out:
# [{'atd_eval_id': 'TVL19-005420',
#   'cross_st': ' CUTTING HORSE LN',
#   'cross_st_block': 1601,
#   'eval_rank': 203,
#   'eval_score': '0',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'id': '5c534c420fd877638727456a',
#   'landmark': '',
#   'location_latitude': 30.417382,
#   'location_longitude': -97.684626,
#   'location_name': ' METRIC BLVD / CUTTING HORSE LN',
#   'primary_st': ' METRIC BLVD',
#   'primary_st_block': 12801,
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ19-003505',
#   'request_status': 'RECENTLY RECEIVED'}]

# %%
exclude_keys = ["id", "landmark"]

data_filtered = [{key: record.get(key) for key in record.keys() if key not in exclude_keys} for record in data_lower_case]

# %% [markdown]
# # Load

# %%
from urllib3.exceptions import HTTPError # we need this to handle HTTPError
from pypgrest import Postgrest

endpoint = "http://schoolofdata.austintexas.io/signal_requests"
auth_token = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJyb2xlIjoic3VwZXJfdXNlciJ9.4QzadgzRW9KlL72SeA1kM4XjlrD21mSfyEkjm-OUbpc"

try:
    pgrest = Postgrest(endpoint, auth_token)
except Exception as e:
    print(pgres.res.text)
    raise e

# %%
pgrest.upsert(data_filtered)
# Out:
# [{'id': 1,
#   'atd_eval_id': 'TVL19-005420',
#   'cross_st': ' CUTTING HORSE LN',
#   'cross_st_block': '1601',
#   'eval_rank': '203',
#   'eval_score': '0',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.417382,
#   'location_longitude': -97.684626,
#   'location_name': ' METRIC BLVD / CUTTING HORSE LN',
#   'primary_st': ' METRIC BLVD',
#   'primary_st_block': '12801',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ19-003505',
#   'request_status': 'RECENTLY RECEIVED'},
#  {'id': 2,
#   'atd_eval_id': 'TVL19-005415',
#   'cross_st': ' JUDSON RD',
#   'cross_st_block': '3401',
#   'eval_rank': '203',
#   'eval_score': '0',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.20976,
#   'location_longitude': -97.725449,
#   'location_name': ' BURLESON RD / JUDSON RD',
#   'primary_st': ' BURLESON RD',
#   'primary_st_block': '5402',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ19-003495',
#   'request_status': 'RECENTLY RECEIVED'},
#  {'id': 3,
#   'atd_eval_id': 'TVL19-005410',
#   'cross_st': ' PASEO NUEVO CIR',
#   'cross_st_block': '5587',
#   'eval_rank': '203',
#   'eval_score': '0',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.1715126,
#   'location_longitude': -97.62754752,
#   'location_name': ' PEARCE LN / PASEO NUEVO CIR',
#   'primary_st': ' PEARCE LN',
#   'primary_st_block': '12302',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ19-003485',
#   'request_status': 'STUDY'},
#  {'id': 4,
#   'atd_eval_id': 'TVL19-005405',
#   'cross_st': ' RALPH ABLANEDO DR',
#   'cross_st_block': '601',
#   'eval_rank': '1',
#   'eval_score': '0',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.1741133,
#   'location_longitude': -97.7989036,
#   'location_name': ' 1ST ST / RALPH ABLANEDO DR',
#   'primary_st': ' 1ST ST',
#   'primary_st_block': '8600',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2019',
#   'request_id': 'REQ19-003470',
#   'request_status': 'RECENTLY RECEIVED'},
#  {'id': 5,
#   'atd_eval_id': 'TVL19-005395',
#   'cross_st': ' RALPH ABLANEDO DR',
#   'cross_st_block': '601',
#   'eval_rank': '1',
#   'eval_score': '0',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.1741133,
#   'location_longitude': -97.7989036,
#   'location_name': ' 1ST ST / RALPH ABLANEDO DR',
#   'primary_st': ' 1ST ST',
#   'primary_st_block': '8600',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2019',
#   'request_id': 'REQ15-001840',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 6,
#   'atd_eval_id': 'TVL18-005390',
#   'cross_st': ' PRATHER LN',
#   'cross_st_block': '2001',
#   'eval_rank': '16',
#   'eval_score': '190',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.2339172,
#   'location_longitude': -97.7857132,
#   'location_name': " MANCHACA RD / PRATHER LN (Ann Richard's School)",
#   'primary_st': ' MANCHACA RD',
#   'primary_st_block': '3712',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ18-003385',
#   'request_status': 'RECENTLY RECEIVED'},
#  {'id': 7,
#   'atd_eval_id': 'TVL18-005385',
#   'cross_st': ' ECLIPSE LN',
#   'cross_st_block': '10201',
#   'eval_rank': '148',
#   'eval_score': '0',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.19172,
#   'location_longitude': -97.877097,
#   'location_name': ' LA CROSSE AVE / ECLIPSE LN',
#   'primary_st': ' LA CROSSE AVE',
#   'primary_st_block': '5300',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2017',
#   'request_id': 'REQ18-003465',
#   'request_status': 'STUDY'},
#  {'id': 8,
#   'atd_eval_id': 'TVL18-005370',
#   'cross_st': ' MANCHACA RD',
#   'cross_st_block': '5801',
#   'eval_rank': '159',
#   'eval_score': '35',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.213845,
#   'location_longitude': -97.800542,
#   'location_name': ' MANCHACA RD / MANCHACA RD (Crockett HS Parking Lot)',
#   'primary_st': ' MANCHACA RD',
#   'primary_st_block': '5800',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ18-003045',
#   'request_status': 'RECENTLY RECEIVED'},
#  {'id': 9,
#   'atd_eval_id': 'TVL18-005365',
#   'cross_st': ' NORTH BLUFF DR',
#   'cross_st_block': '100',
#   'eval_rank': '2',
#   'eval_score': '390',
#   'eval_status': 'COMPLETED',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.198144,
#   'location_longitude': -97.776758,
#   'location_name': ' CONGRESS AVE / NORTH BLUFF DR',
#   'primary_st': ' CONGRESS AVE',
#   'primary_st_block': '6221',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ17-002715',
#   'request_status': 'RECENTLY RECEIVED'},
#  {'id': 10,
#   'atd_eval_id': 'TVL18-005360',
#   'cross_st': ' BANNOCKBURN DR',
#   'cross_st_block': '3501',
#   'eval_rank': '173',
#   'eval_score': '25',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.212762,
#   'location_longitude': -97.831017,
#   'location_name': ' BRODIE LN / BANNOCKBURN DR',
#   'primary_st': ' BRODIE LN',
#   'primary_st_block': '6912',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ18-002975',
#   'request_status': 'RECENTLY RECEIVED'},
#  {'id': 11,
#   'atd_eval_id': 'TVL18-005355',
#   'cross_st': ' MANCHACA RD',
#   'cross_st_block': '5801',
#   'eval_rank': '148',
#   'eval_score': '0',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.213845,
#   'location_longitude': -97.800542,
#   'location_name': ' MANCHACA RD / MANCHACA RD (Crockett HS Parking Lot)',
#   'primary_st': ' MANCHACA RD',
#   'primary_st_block': '5800',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2017',
#   'request_id': 'REQ18-003045',
#   'request_status': 'RECENTLY RECEIVED'},
#  {'id': 12,
#   'atd_eval_id': 'TVL18-005350',
#   'cross_st': ' ASA DR',
#   'cross_st_block': '6300',
#   'eval_rank': '186',
#   'eval_score': '10',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.165557,
#   'location_longitude': -97.741643,
#   'location_name': ' SALT SPRINGS DR / ASA DR',
#   'primary_st': ' SALT SPRINGS DR',
#   'primary_st_block': '7306',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ17-002855',
#   'request_status': 'RECENTLY RECEIVED'},
#  {'id': 13,
#   'atd_eval_id': 'TVL18-005345',
#   'cross_st': ' CENTER LINE PASS',
#   'cross_st_block': '13300',
#   'eval_rank': '167',
#   'eval_score': '30',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.414889,
#   'location_longitude': -97.667091,
#   'location_name': ' CENTER RIDGE DR / CENTER LINE PASS',
#   'primary_st': ' CENTER RIDGE DR',
#   'primary_st_block': '400',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ18-003460',
#   'request_status': 'RECENTLY RECEIVED'},
#  {'id': 14,
#   'atd_eval_id': 'TVL18-005340',
#   'cross_st': ' MELLOW MEADOW DR',
#   'cross_st_block': '12300',
#   'eval_rank': '203',
#   'eval_score': '0',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.459944,
#   'location_longitude': -97.798066,
#   'location_name': ' LAKE CREEK PKWY / MELLOW MEADOW DR (Westwood High School)',
#   'primary_st': ' LAKE CREEK PKWY',
#   'primary_st_block': '10422',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ18-003455',
#   'request_status': 'RECENTLY RECEIVED'},
#  {'id': 15,
#   'atd_eval_id': 'TVL18-005330',
#   'cross_st': '  ',
#   'cross_st_block': '0',
#   'eval_rank': '203',
#   'eval_score': '0',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.397666,
#   'location_longitude': -97.679595,
#   'location_name': '11912 BLK N LAMAR BLVD (Walnut Park Crossing)',
#   'primary_st': ' LAMAR BLVD',
#   'primary_st_block': '11912',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ18-003450',
#   'request_status': 'RECENTLY RECEIVED'},
#  {'id': 16,
#   'atd_eval_id': 'TVL18-005325',
#   'cross_st': ' 31ST ST',
#   'cross_st_block': '601',
#   'eval_rank': '91',
#   'eval_score': '90',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.2978306,
#   'location_longitude': -97.7412338,
#   'location_name': ' GUADALUPE ST / 31ST ST',
#   'primary_st': ' GUADALUPE ST',
#   'primary_st_block': '3100',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ18-003445',
#   'request_status': 'RECENTLY RECEIVED'},
#  {'id': 17,
#   'atd_eval_id': 'TVL18-005320',
#   'cross_st': ' GREENSLOPE DR',
#   'cross_st_block': '7900',
#   'eval_rank': '56',
#   'eval_score': '130',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.367509,
#   'location_longitude': -97.752772,
#   'location_name': ' SPICEWOOD SPRINGS RD / GREENSLOPE DR (WB intersection)',
#   'primary_st': ' SPICEWOOD SPRINGS RD',
#   'primary_st_block': '4004',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ17-002375',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 18,
#   'atd_eval_id': 'TVL18-005315',
#   'cross_st': '  ',
#   'cross_st_block': '0',
#   'eval_rank': '24',
#   'eval_score': '180',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.271393,
#   'location_longitude': -97.631979,
#   'location_name': '9300 BLK FM 969 RD (Discovery School)',
#   'primary_st': 'FM 969 RD',
#   'primary_st_block': '9300',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ17-002370',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 19,
#   'atd_eval_id': 'TVL18-005310',
#   'cross_st': ' BARTON SPRINGS RD',
#   'cross_st_block': '601',
#   'eval_rank': '133',
#   'eval_score': '55',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.258851,
#   'location_longitude': -97.751391,
#   'location_name': ' BARTON SPRINGS RD / BARTON SPRINGS RD (Town Lake Center)',
#   'primary_st': ' BARTON SPRINGS RD',
#   'primary_st_block': '600',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ17-002445',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 20,
#   'atd_eval_id': 'TVL18-005305',
#   'cross_st': ' ROCKRIDGE DR',
#   'cross_st_block': '2522',
#   'eval_rank': '85',
#   'eval_score': '95',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.182987,
#   'location_longitude': -97.75351,
#   'location_name': ' WILLIAM CANNON DR / ROCKRIDGE DR',
#   'primary_st': ' WILLIAM CANNON DR',
#   'primary_st_block': '4401',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ17-002425',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 21,
#   'atd_eval_id': 'TVL18-005300',
#   'cross_st': ' LAZY CREEK DR',
#   'cross_st_block': '7200',
#   'eval_rank': '41',
#   'eval_score': '150',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.315159,
#   'location_longitude': -97.657018,
#   'location_name': ' PECAN BROOK DR / LAZY CREEK DR',
#   'primary_st': ' PECAN BROOK DR',
#   'primary_st_block': '5110',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ17-002465',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 22,
#   'atd_eval_id': 'TVL18-005295',
#   'cross_st': ' GROVER AVE',
#   'cross_st_block': '6850',
#   'eval_rank': '74',
#   'eval_score': '105',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.339214,
#   'location_longitude': -97.723761,
#   'location_name': ' JUSTIN LN / GROVER AVE',
#   'primary_st': ' JUSTIN LN',
#   'primary_st_block': '1200',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ17-002485',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 23,
#   'atd_eval_id': 'TVL18-005290',
#   'cross_st': ' GRADY DR',
#   'cross_st_block': '701',
#   'eval_rank': '41',
#   'eval_score': '150',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.375898,
#   'location_longitude': -97.68976,
#   'location_name': ' LAMAR BLVD / GRADY DR',
#   'primary_st': ' LAMAR BLVD',
#   'primary_st_block': '10700',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ17-002490',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 24,
#   'atd_eval_id': 'TVL18-005285',
#   'cross_st': ' CROSSCREEK DR',
#   'cross_st_block': '3301',
#   'eval_rank': '146',
#   'eval_score': '50',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.371437,
#   'location_longitude': -97.737406,
#   'location_name': ' SHOAL CREEK BLVD / CROSSCREEK DR',
#   'primary_st': ' SHOAL CREEK BLVD',
#   'primary_st_block': '8200',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ17-002495',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 25,
#   'atd_eval_id': 'TVL18-005280',
#   'cross_st': ' SMITH RD',
#   'cross_st_block': '1914',
#   'eval_rank': '157',
#   'eval_score': '40',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.259279,
#   'location_longitude': -97.675271,
#   'location_name': ' ED BLUESTEIN BLVD / SMITH RD',
#   'primary_st': ' ED BLUESTEIN BLVD',
#   'primary_st_block': '1727',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ17-002510',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 26,
#   'atd_eval_id': 'TVL18-005275',
#   'cross_st': ' ORLAND BLVD',
#   'cross_st_block': '601',
#   'eval_rank': '173',
#   'eval_score': '25',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.216085,
#   'location_longitude': -97.775996,
#   'location_name': ' 1ST ST / ORLAND BLVD',
#   'primary_st': ' 1ST ST',
#   'primary_st_block': '4531',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ17-002515',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 27,
#   'atd_eval_id': 'TVL18-005270',
#   'cross_st': ' BRODIE LN',
#   'cross_st_block': '6800',
#   'eval_rank': '60',
#   'eval_score': '120',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.216291,
#   'location_longitude': -97.828888,
#   'location_name': ' BRODIE LN / BRODIE LN',
#   'primary_st': ' BRODIE LN',
#   'primary_st_block': '6500',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ17-002525',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 28,
#   'atd_eval_id': 'TVL18-005265',
#   'cross_st': ' WEST AVE',
#   'cross_st_block': '226',
#   'eval_rank': '41',
#   'eval_score': '150',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.267619,
#   'location_longitude': -97.751581,
#   'location_name': ' 3RD ST / WEST AVE',
#   'primary_st': ' 3RD ST',
#   'primary_st_block': '800',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ17-002555',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 29,
#   'atd_eval_id': 'TVL18-005260',
#   'cross_st': ' FENTONRIDGE DR',
#   'cross_st_block': '2601',
#   'eval_rank': '173',
#   'eval_score': '25',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.20262,
#   'location_longitude': -97.818097,
#   'location_name': ' WEST GATE BLVD / FENTONRIDGE DR',
#   'primary_st': ' WEST GATE BLVD',
#   'primary_st_block': '7302',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ17-002560',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 30,
#   'atd_eval_id': 'TVL18-005255',
#   'cross_st': ' BRYONHALL DR',
#   'cross_st_block': '2701',
#   'eval_rank': '159',
#   'eval_score': '35',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.205029,
#   'location_longitude': -97.816522,
#   'location_name': ' WEST GATE BLVD / BRYONHALL DR',
#   'primary_st': ' WEST GATE BLVD',
#   'primary_st_block': '7008',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ17-002585',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 31,
#   'atd_eval_id': 'TVL18-005250',
#   'cross_st': ' GREAT HILLS TRL',
#   'cross_st_block': '10000',
#   'eval_rank': '16',
#   'eval_score': '190',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.393728,
#   'location_longitude': -97.744163,
#   'location_name': ' GREAT HILLS TRL / GREAT HILLS TRL (between Michaels and Target)',
#   'primary_st': ' GREAT HILLS TRL',
#   'primary_st_block': '10000',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ17-002665',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 32,
#   'atd_eval_id': 'TVL18-005245',
#   'cross_st': ' RALPH ABLANEDO DR',
#   'cross_st_block': '101',
#   'eval_rank': '4',
#   'eval_score': '280',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.172955,
#   'location_longitude': -97.785284,
#   'location_name': ' CONGRESS AVE / RALPH ABLANEDO DR',
#   'primary_st': ' CONGRESS AVE',
#   'primary_st_block': '8400',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ17-002670',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 33,
#   'atd_eval_id': 'TVL18-005240',
#   'cross_st': ' RENFERT WAY',
#   'cross_st_block': '12100',
#   'eval_rank': '186',
#   'eval_score': '10',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.4089,
#   'location_longitude': -97.706143,
#   'location_name': ' PARK BEND DR / RENFERT WAY',
#   'primary_st': ' PARK BEND DR',
#   'primary_st_block': '2400',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ17-002700',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 34,
#   'atd_eval_id': 'TVL18-005235',
#   'cross_st': ' ASPEN GLENN BLVD',
#   'cross_st_block': '7500',
#   'eval_rank': '94',
#   'eval_score': '85',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.332219,
#   'location_longitude': -97.686614,
#   'location_name': ' MC KINNEY FALLS PKWY / ASPEN GLENN BLVD',
#   'primary_st': ' MC KINNEY FALLS PKWY',
#   'primary_st_block': '3600',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ16-002340',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 35,
#   'atd_eval_id': 'TVL18-005230',
#   'cross_st': ' RIALTO BLVD',
#   'cross_st_block': '6301',
#   'eval_rank': '10',
#   'eval_score': '210',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'Private',
#   'location_latitude': 30.251808,
#   'location_longitude': -97.85876,
#   'location_name': ' SOUTHWEST PKWY / RIALTO BLVD',
#   'primary_st': ' SOUTHWEST PKWY',
#   'primary_st_block': '6701',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ16-002350',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 36,
#   'atd_eval_id': 'TVL18-005225',
#   'cross_st': ' QUICKSILVER BLVD',
#   'cross_st_block': '2100',
#   'eval_rank': '34',
#   'eval_score': '165',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.177672,
#   'location_longitude': -97.769822,
#   'location_name': ' BLUFF SPRINGS RD / QUICKSILVER BLVD',
#   'primary_st': ' BLUFF SPRINGS RD',
#   'primary_st_block': '7400',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ17-002360',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 37,
#   'atd_eval_id': 'TVL18-005220',
#   'cross_st': ' BROADHILL DR',
#   'cross_st_block': '4600',
#   'eval_rank': '121',
#   'eval_score': '65',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.286454,
#   'location_longitude': -97.676387,
#   'location_name': ' MARTIN LUTHER KING JR BLVD / BROADHILL DR',
#   'primary_st': ' MARTIN LUTHER KING JR BLVD',
#   'primary_st_block': '5066',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ17-002405',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 38,
#   'atd_eval_id': 'TVL18-005215',
#   'cross_st': ' DESSAU RD',
#   'cross_st_block': '12000',
#   'eval_rank': '10',
#   'eval_score': '210',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.380566,
#   'location_longitude': -97.65293,
#   'location_name': ' DESSAU RD / DESSAU RD',
#   'primary_st': ' DESSAU RD',
#   'primary_st_block': '12030',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ17-002430',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 39,
#   'atd_eval_id': 'TVL18-005210',
#   'cross_st': ' ADIRONDACK TRL',
#   'cross_st_block': '8546',
#   'eval_rank': '48',
#   'eval_score': '140',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.383253,
#   'location_longitude': -97.765878,
#   'location_name': ' SPICEWOOD SPRINGS RD / ADIRONDACK TRL',
#   'primary_st': ' SPICEWOOD SPRINGS RD',
#   'primary_st_block': '5300',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ17-002480',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 40,
#   'atd_eval_id': 'TVL18-005205',
#   'cross_st': ' AVENUE G ',
#   'cross_st_block': '4500',
#   'eval_rank': '16',
#   'eval_score': '190',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.307714,
#   'location_longitude': -97.726505,
#   'location_name': ' 45TH ST / AVENUE G ',
#   'primary_st': ' 45TH ST',
#   'primary_st_block': '200',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ17-002610',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 41,
#   'atd_eval_id': 'TVL18-005200',
#   'cross_st': ' NORTHWOOD RD',
#   'cross_st_block': '1701',
#   'eval_rank': '67',
#   'eval_score': '110',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.300101,
#   'location_longitude': -97.75619,
#   'location_name': ' JEFFERSON ST / NORTHWOOD RD',
#   'primary_st': ' JEFFERSON ST',
#   'primary_st_block': '2800',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ17-002630',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 42,
#   'atd_eval_id': 'TVL18-005195',
#   'cross_st': ' AMARILLO AVE',
#   'cross_st_block': '13000',
#   'eval_rank': '6',
#   'eval_score': '230',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.441915,
#   'location_longitude': -97.747673,
#   'location_name': ' MC NEIL DR / AMARILLO AVE',
#   'primary_st': ' MC NEIL DR',
#   'primary_st_block': '6264',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ17-002655',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 43,
#   'atd_eval_id': 'TVL18-005190',
#   'cross_st': ' FOREST VIEW DR',
#   'cross_st_block': '906',
#   'eval_rank': '190',
#   'eval_score': '5',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.290874,
#   'location_longitude': -97.792994,
#   'location_name': ' REDBUD TRL / FOREST VIEW DR',
#   'primary_st': ' REDBUD TRL',
#   'primary_st_block': '3604',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ17-002450',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 44,
#   'atd_eval_id': 'TVL18-005185',
#   'cross_st': ' ROBERT T MARTINEZ JR ST',
#   'cross_st_block': '600',
#   'eval_rank': '48',
#   'eval_score': '140',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.2602953,
#   'location_longitude': -97.7186104,
#   'location_name': ' 6TH ST / ROBERT T MARTINEZ JR ST',
#   'primary_st': ' 6TH ST',
#   'primary_st_block': '1900',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ14-000275',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 45,
#   'atd_eval_id': 'TVL18-005180',
#   'cross_st': ' WHISPERING VALLEY DR',
#   'cross_st_block': '4400',
#   'eval_rank': '36',
#   'eval_score': '160',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.4125099,
#   'location_longitude': -97.7315926,
#   'location_name': ' DUVAL RD / WHISPERING VALLEY DR',
#   'primary_st': ' DUVAL RD',
#   'primary_st_block': '4400',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ15-000585',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 46,
#   'atd_eval_id': 'TVL18-005175',
#   'cross_st': ' WALNUT AVE',
#   'cross_st_block': '3100',
#   'eval_rank': '107',
#   'eval_score': '75',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.2850712,
#   'location_longitude': -97.7141833,
#   'location_name': ' MANOR RD / WALNUT AVE',
#   'primary_st': ' MANOR RD',
#   'primary_st_block': '2600',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ14-000250',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 47,
#   'atd_eval_id': 'TVL18-005170',
#   'cross_st': '  ',
#   'cross_st_block': '0',
#   'eval_rank': '24',
#   'eval_score': '180',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.41334,
#   'location_longitude': -97.65302,
#   'location_name': '400 BLK E HOWARD LN (Cape Horn Rd.)',
#   'primary_st': ' HOWARD LN',
#   'primary_st_block': '400',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ15-000675',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 48,
#   'atd_eval_id': 'TVL18-005165',
#   'cross_st': ' VERTEX BLVD',
#   'cross_st_block': '8601',
#   'eval_rank': '85',
#   'eval_score': '95',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.1578485,
#   'location_longitude': -97.7523808,
#   'location_name': ' NUCKOLS CROSSING RD / VERTEX BLVD',
#   'primary_st': ' NUCKOLS CROSSING RD',
#   'primary_st_block': '8600',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ16-000905',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 49,
#   'atd_eval_id': 'TVL18-005160',
#   'cross_st': ' PARKSTONE HEIGHTS DR',
#   'cross_st_block': '4101',
#   'eval_rank': '36',
#   'eval_score': '160',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.2716462,
#   'location_longitude': -97.8176015,
#   'location_name': ' CAPITAL OF TEXAS HWY / PARKSTONE HEIGHTS DR',
#   'primary_st': ' CAPITAL OF TEXAS HWY',
#   'primary_st_block': '1500',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ15-000630',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 50,
#   'atd_eval_id': 'TVL18-005155',
#   'cross_st': ' CIMARRON TRL',
#   'cross_st_block': '2001',
#   'eval_rank': '100',
#   'eval_score': '80',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.2270336,
#   'location_longitude': -97.79016423,
#   'location_name': ' MANCHACA RD / CIMARRON TRL',
#   'primary_st': ' MANCHACA RD',
#   'primary_st_block': '4500',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ15-000670',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 51,
#   'atd_eval_id': 'TVL18-005150',
#   'cross_st': ' WEST AVE',
#   'cross_st_block': '900',
#   'eval_rank': '116',
#   'eval_score': '70',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.27305,
#   'location_longitude': -97.7495429,
#   'location_name': ' 9TH ST / WEST AVE',
#   'primary_st': ' 9TH ST',
#   'primary_st_block': '800',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ16-000950',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 52,
#   'atd_eval_id': 'TVL18-005145',
#   'cross_st': '  ',
#   'cross_st_block': '0',
#   'eval_rank': '12',
#   'eval_score': '200',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.39053,
#   'location_longitude': -97.68245,
#   'location_name': '11850 BLK N LAMAR BLVD (Brentwood Christian School)',
#   'primary_st': ' LAMAR BLVD',
#   'primary_st_block': '11850',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ15-000835',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 53,
#   'atd_eval_id': 'TVL18-005140',
#   'cross_st': ' CROWNSPOINT DR',
#   'cross_st_block': '2001',
#   'eval_rank': '29',
#   'eval_score': '175',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.1776619,
#   'location_longitude': -97.8215442,
#   'location_name': ' MANCHACA RD / CROWNSPOINT DR',
#   'primary_st': ' MANCHACA RD',
#   'primary_st_block': '9429',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ16-000815',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 54,
#   'atd_eval_id': 'TVL18-005135',
#   'cross_st': ' OLD BEE CAVES RD',
#   'cross_st_block': '6701',
#   'eval_rank': '12',
#   'eval_score': '200',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.2339807,
#   'location_longitude': -97.8712305,
#   'location_name': 'US 290 HWY / OLD BEE CAVES RD',
#   'primary_st': 'US 290 HWY',
#   'primary_st_block': '6836',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ16-000915',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 55,
#   'atd_eval_id': 'TVL18-005130',
#   'cross_st': ' SAN MARCOS ST',
#   'cross_st_block': '600',
#   'eval_rank': '15',
#   'eval_score': '195',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.2651158,
#   'location_longitude': -97.7325274,
#   'location_name': ' 6TH ST / SAN MARCOS ST',
#   'primary_st': ' 6TH ST',
#   'primary_st_block': '900',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ15-000710',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 56,
#   'atd_eval_id': 'TVL18-005125',
#   'cross_st': ' CORIANDER DR',
#   'cross_st_block': '1701',
#   'eval_rank': '41',
#   'eval_score': '150',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.220241,
#   'location_longitude': -97.6934937,
#   'location_name': ' RIVERSIDE DR / CORIANDER DR',
#   'primary_st': ' RIVERSIDE DR',
#   'primary_st_block': '7301',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ16-000840',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 57,
#   'atd_eval_id': 'TVL18-005120',
#   'cross_st': ' TANNEHILL LN',
#   'cross_st_block': '4414',
#   'eval_rank': '107',
#   'eval_score': '75',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.283966,
#   'location_longitude': -97.6716326,
#   'location_name': ' WEBBERVILLE RD / TANNEHILL LN',
#   'primary_st': ' WEBBERVILLE RD',
#   'primary_st_block': '1918',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ16-000810',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 58,
#   'atd_eval_id': 'TVL18-005115',
#   'cross_st': ' MULLEN DR',
#   'cross_st_block': '7800',
#   'eval_rank': '41',
#   'eval_score': '150',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.3538418,
#   'location_longitude': -97.72601836,
#   'location_name': ' ANDERSON LN / MULLEN DR',
#   'primary_st': ' ANDERSON LN',
#   'primary_st_block': '1900',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ15-000725',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 59,
#   'atd_eval_id': 'TVL18-005110',
#   'cross_st': ' BRODIE LN',
#   'cross_st_block': '8601',
#   'eval_rank': '121',
#   'eval_score': '65',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.19862,
#   'location_longitude': -97.840158,
#   'location_name': ' BRODIE LN / BRODIE LN (Villages of Bella Vista & Ridgeview Apts.)',
#   'primary_st': ' BRODIE LN',
#   'primary_st_block': '8300',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ16-000845',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 60,
#   'atd_eval_id': 'TVL18-005105',
#   'cross_st': ' OLDFORT HILL DR',
#   'cross_st_block': '4700',
#   'eval_rank': '190',
#   'eval_score': '5',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.28656,
#   'location_longitude': -97.6752189,
#   'location_name': ' MARTIN LUTHER KING JR BLVD / OLDFORT HILL DR',
#   'primary_st': ' MARTIN LUTHER KING JR BLVD',
#   'primary_st_block': '5188',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ15-000755',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 61,
#   'atd_eval_id': 'TVL18-005100',
#   'cross_st': ' 1ST ST',
#   'cross_st_block': '10800',
#   'eval_rank': '16',
#   'eval_score': '190',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.149516,
#   'location_longitude': -97.80269,
#   'location_name': ' 1ST ST / 1ST ST (Akins High School - Main Entrance)',
#   'primary_st': ' 1ST ST',
#   'primary_st_block': '10700',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ15-000770',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 62,
#   'atd_eval_id': 'TVL18-005095',
#   'cross_st': ' AVERY ISLAND AVE',
#   'cross_st_block': '6411',
#   'eval_rank': '32',
#   'eval_score': '170',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.4400979,
#   'location_longitude': -97.7524616,
#   'location_name': ' MC NEIL DR / AVERY ISLAND AVE',
#   'primary_st': ' MC NEIL DR',
#   'primary_st_block': '6411',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ15-000780',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 63,
#   'atd_eval_id': 'TVL18-005090',
#   'cross_st': ' SOUTH INDUSTRIAL DR',
#   'cross_st_block': '4201',
#   'eval_rank': '38',
#   'eval_score': '155',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.208818,
#   'location_longitude': -97.744413,
#   'location_name': ' ST ELMO RD / SOUTH INDUSTRIAL DR',
#   'primary_st': ' ST ELMO RD',
#   'primary_st_block': '2023',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ15-000745',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 64,
#   'atd_eval_id': 'TVL18-005085',
#   'cross_st': ' WEST AVE',
#   'cross_st_block': '800',
#   'eval_rank': '133',
#   'eval_score': '55',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.272101,
#   'location_longitude': -97.7499129,
#   'location_name': ' 8TH ST / WEST AVE',
#   'primary_st': ' 8TH ST',
#   'primary_st_block': '700',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ16-000945',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 65,
#   'atd_eval_id': 'TVL18-005080',
#   'cross_st': ' PONCIANA DR',
#   'cross_st_block': '5101',
#   'eval_rank': '133',
#   'eval_score': '55',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.202013,
#   'location_longitude': -97.7546387,
#   'location_name': ' FREIDRICH LN / PONCIANA DR',
#   'primary_st': ' FREIDRICH LN',
#   'primary_st_block': '5100',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ16-000940',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 66,
#   'atd_eval_id': 'TVL18-005075',
#   'cross_st': ' PATTERSON AVE',
#   'cross_st_block': '600',
#   'eval_rank': '94',
#   'eval_score': '85',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.2767801,
#   'location_longitude': -97.7662733,
#   'location_name': ' 6TH ST / PATTERSON AVE',
#   'primary_st': ' 6TH ST',
#   'primary_st_block': '1800',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ16-000925',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 67,
#   'atd_eval_id': 'TVL18-005070',
#   'cross_st': ' CENTENNIAL TRL',
#   'cross_st_block': '10700',
#   'eval_rank': '100',
#   'eval_score': '80',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.4502221,
#   'location_longitude': -97.8191309,
#   'location_name': ' ANDERSON MILL RD / CENTENNIAL TRL',
#   'primary_st': ' ANDERSON MILL RD',
#   'primary_st_block': '11300',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ16-000920',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 68,
#   'atd_eval_id': 'TVL18-005065',
#   'cross_st': '  ',
#   'cross_st_block': '0',
#   'eval_rank': '182',
#   'eval_score': '15',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.253467,
#   'location_longitude': -97.900595,
#   'location_name': '8660 BLK W SH 71 (Life Austin Church)',
#   'primary_st': 'SH 71 ',
#   'primary_st_block': '8660',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ16-000900',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 69,
#   'atd_eval_id': 'TVL18-005060',
#   'cross_st': ' HARRISGLENN DR',
#   'cross_st_block': '13300',
#   'eval_rank': '12',
#   'eval_score': '200',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.4062557,
#   'location_longitude': -97.64217936,
#   'location_name': ' HOWARD LN / HARRISGLENN DR',
#   'primary_st': ' HOWARD LN',
#   'primary_st_block': '1113',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ16-000870',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 70,
#   'atd_eval_id': 'TVL18-005055',
#   'cross_st': ' REDWATER DR',
#   'cross_st_block': '1801',
#   'eval_rank': '133',
#   'eval_score': '55',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.1680241,
#   'location_longitude': -97.82621,
#   'location_name': ' MANCHACA RD / REDWATER DR',
#   'primary_st': ' MANCHACA RD',
#   'primary_st_block': '10000',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ16-000855',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 71,
#   'atd_eval_id': 'TVL18-005050',
#   'cross_st': ' JEFFERSON ST',
#   'cross_st_block': '2814',
#   'eval_rank': '60',
#   'eval_score': '120',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.3018088,
#   'location_longitude': -97.7551691,
#   'location_name': ' 29TH ST / JEFFERSON ST',
#   'primary_st': ' 29TH ST',
#   'primary_st_block': '1700',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ16-000850',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 72,
#   'atd_eval_id': 'TVL18-005045',
#   'cross_st': ' STRATFORD DR',
#   'cross_st_block': '3301',
#   'eval_rank': '146',
#   'eval_score': '50',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.2900719,
#   'location_longitude': -97.790691,
#   'location_name': ' REDBUD TRL / STRATFORD DR',
#   'primary_st': ' REDBUD TRL',
#   'primary_st_block': '3470',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ16-000830',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 73,
#   'atd_eval_id': 'TVL18-005040',
#   'cross_st': ' WATSON ST',
#   'cross_st_block': '7800',
#   'eval_rank': '85',
#   'eval_score': '95',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.3492126,
#   'location_longitude': -97.7162781,
#   'location_name': ' ANDERSON LN / WATSON ST',
#   'primary_st': ' ANDERSON LN',
#   'primary_st_block': '1100',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ15-000795',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 74,
#   'atd_eval_id': 'TVL18-005035',
#   'cross_st': ' KENDRICK LN',
#   'cross_st_block': '0',
#   'eval_rank': '121',
#   'eval_score': '65',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.1864433,
#   'location_longitude': -97.9136276,
#   'location_name': 'SH 45  / KENDRICK LN',
#   'primary_st': 'SH 45 ',
#   'primary_st_block': '7400',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ15-000790',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 75,
#   'atd_eval_id': 'TVL18-005030',
#   'cross_st': ' SPRUCE CANYON DR',
#   'cross_st_block': '11511',
#   'eval_rank': '182',
#   'eval_score': '15',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.1842809,
#   'location_longitude': -97.9057465,
#   'location_name': 'SH 45  / SPRUCE CANYON DR',
#   'primary_st': 'SH 45 ',
#   'primary_st_block': '6900',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ15-000785',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 76,
#   'atd_eval_id': 'TVL18-005025',
#   'cross_st': ' HEARN ST',
#   'cross_st_block': '500',
#   'eval_rank': '53',
#   'eval_score': '135',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.278539,
#   'location_longitude': -97.773179,
#   'location_name': ' LAKE AUSTIN BLVD / HEARN ST',
#   'primary_st': ' LAKE AUSTIN BLVD',
#   'primary_st_block': '2500',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ15-000775',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 77,
#   'atd_eval_id': 'TVL18-005020',
#   'cross_st': ' READ GRANBERRY TRL',
#   'cross_st_block': '2700',
#   'eval_rank': '116',
#   'eval_score': '70',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.385552,
#   'location_longitude': -97.7236358,
#   'location_name': ' BURNET RD / READ GRANBERRY TRL',
#   'primary_st': ' BURNET RD',
#   'primary_st_block': '10000',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ15-000750',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 78,
#   'atd_eval_id': 'TVL18-005015',
#   'cross_st': ' ANITA DR',
#   'cross_st_block': '1801',
#   'eval_rank': '159',
#   'eval_score': '35',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.2548272,
#   'location_longitude': -97.7720312,
#   'location_name': ' BLUEBONNET LN / ANITA DR',
#   'primary_st': ' BLUEBONNET LN',
#   'primary_st_block': '1604',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ15-000715',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 79,
#   'atd_eval_id': 'TVL18-005010',
#   'cross_st': ' RABB RD',
#   'cross_st_block': '1401',
#   'eval_rank': '121',
#   'eval_score': '65',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.2580434,
#   'location_longitude': -97.7727899,
#   'location_name': ' AZIE MORTON RD / RABB RD',
#   'primary_st': ' AZIE MORTON RD',
#   'primary_st_block': '1300',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ15-000665',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 80,
#   'atd_eval_id': 'TVL18-005005',
#   'cross_st': ' SHILOH DR',
#   'cross_st_block': '2001',
#   'eval_rank': '78',
#   'eval_score': '100',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.1912073,
#   'location_longitude': -97.8129334,
#   'location_name': ' MANCHACA RD / SHILOH DR',
#   'primary_st': ' MANCHACA RD',
#   'primary_st_block': '7826',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ15-000660',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 81,
#   'atd_eval_id': 'TVL18-005000',
#   'cross_st': ' ZUNIGA DR',
#   'cross_st_block': '9401',
#   'eval_rank': '133',
#   'eval_score': '55',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.1965319,
#   'location_longitude': -97.8602275,
#   'location_name': ' SLAUGHTER LN / ZUNIGA DR',
#   'primary_st': ' SLAUGHTER LN',
#   'primary_st_block': '4500',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ15-000655',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 82,
#   'atd_eval_id': 'TVL18-004995',
#   'cross_st': ' DORCHESTER DR',
#   'cross_st_block': '6200',
#   'eval_rank': '182',
#   'eval_score': '15',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.3130533,
#   'location_longitude': -97.6861015,
#   'location_name': ' WHELESS LN / DORCHESTER DR',
#   'primary_st': ' WHELESS LN',
#   'primary_st_block': '2012',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ15-000650',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 83,
#   'atd_eval_id': 'TVL18-004990',
#   'cross_st': ' PRESSLER ST',
#   'cross_st_block': '600',
#   'eval_rank': '38',
#   'eval_score': '155',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.273898,
#   'location_longitude': -97.760207,
#   'location_name': ' 6TH ST / PRESSLER ST',
#   'primary_st': ' 6TH ST',
#   'primary_st_block': '1300',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ15-000635',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 84,
#   'atd_eval_id': 'TVL18-004985',
#   'cross_st': ' DOUBLE EAGLE PASS',
#   'cross_st_block': '10200',
#   'eval_rank': '190',
#   'eval_score': '5',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.5017547,
#   'location_longitude': -97.7568588,
#   'location_name': ' AVERY RANCH BLVD / DOUBLE EAGLE PASS',
#   'primary_st': ' AVERY RANCH BLVD',
#   'primary_st_block': '15700',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ15-000600',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 85,
#   'atd_eval_id': 'TVL18-004980',
#   'cross_st': ' HIGHLAND HILLS CIR',
#   'cross_st_block': '5700',
#   'eval_rank': '190',
#   'eval_score': '5',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.3395348,
#   'location_longitude': -97.7593307,
#   'location_name': 'FM 2222 RD / HIGHLAND HILLS CIR',
#   'primary_st': 'FM 2222 RD',
#   'primary_st_block': '3552',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ15-000595',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 86,
#   'atd_eval_id': 'TVL18-004975',
#   'cross_st': ' SENDERO HILLS PKWY',
#   'cross_st_block': '6500',
#   'eval_rank': '100',
#   'eval_score': '80',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'TRAFFIC',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.2975818,
#   'location_longitude': -97.6408876,
#   'location_name': ' LOYOLA LN / SENDERO HILLS PKWY',
#   'primary_st': ' LOYOLA LN',
#   'primary_st_block': '7106',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2018',
#   'request_id': 'REQ15-000580',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 87,
# ...
#   'primary_st': ' OLTORF ST',
#   'primary_st_block': '900',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2017',
#   'request_id': 'REQ17-002355',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 972,
#   'atd_eval_id': 'PVL17-001815',
#   'cross_st': ' 12TH ST',
#   'cross_st_block': '500',
#   'eval_rank': '62',
#   'eval_score': '390',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'PHB',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.2751044,
#   'location_longitude': -97.7452341,
#   'location_name': ' SAN ANTONIO ST / 12TH ST',
#   'primary_st': ' SAN ANTONIO ST',
#   'primary_st_block': '1200',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2017',
#   'request_id': 'REQ14-002905',
#   'request_status': 'NOT RECOMMENDED'},
#  {'id': 973,
#   'atd_eval_id': 'PVL17-001800',
#   'cross_st': '  ',
#   'cross_st_block': '0',
#   'eval_rank': '1',
#   'eval_score': '588',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'PHB',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.331023,
#   'location_longitude': -97.70969,
#   'location_name': '300 BLK E HUNTLAND DR (St. Francis School)',
#   'primary_st': ' HUNTLAND DR',
#   'primary_st_block': '300',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2017',
#   'request_id': 'REQ17-002590',
#   'request_status': 'STUDY'},
#  {'id': 974,
#   'atd_eval_id': 'PVL17-001795',
#   'cross_st': ' BRYONHALL DR',
#   'cross_st_block': '2701',
#   'eval_rank': '127',
#   'eval_score': '147',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'PHB',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.205029,
#   'location_longitude': -97.816522,
#   'location_name': ' WEST GATE BLVD / BRYONHALL DR',
#   'primary_st': ' WEST GATE BLVD',
#   'primary_st_block': '7008',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2017',
#   'request_id': 'REQ17-002890',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 975,
#   'atd_eval_id': 'PVL17-001790',
#   'cross_st': ' BERKETT DR',
#   'cross_st_block': '2709',
#   'eval_rank': '60',
#   'eval_score': '391',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'PHB',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.215194,
#   'location_longitude': -97.814073,
#   'location_name': ' WEST GATE BLVD / BERKETT DR',
#   'primary_st': ' WEST GATE BLVD',
#   'primary_st_block': '6108',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2017',
#   'request_id': 'REQ17-002575',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 976,
#   'atd_eval_id': 'PVL17-001785',
#   'cross_st': ' FENTONRIDGE DR',
#   'cross_st_block': '2601',
#   'eval_rank': '119',
#   'eval_score': '226',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'PHB',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.20262,
#   'location_longitude': -97.818097,
#   'location_name': ' WEST GATE BLVD / FENTONRIDGE DR',
#   'primary_st': ' WEST GATE BLVD',
#   'primary_st_block': '7302',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2017',
#   'request_id': 'REQ17-002885',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 977,
#   'atd_eval_id': 'PVL17-001780',
#   'cross_st': ' TISDALE DR',
#   'cross_st_block': '7600',
#   'eval_rank': '68',
#   'eval_score': '380',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'PHB',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.350666,
#   'location_longitude': -97.719295,
#   'location_name': ' ANDERSON LN / TISDALE DR',
#   'primary_st': ' ANDERSON LN',
#   'primary_st_block': '1308',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2017',
#   'request_id': 'REQ17-002550',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 978,
#   'atd_eval_id': 'PVL17-001775',
#   'cross_st': ' JOSEPH CLAYTON DR',
#   'cross_st_block': '10900',
#   'eval_rank': '52',
#   'eval_score': '400',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'PHB',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.376166,
#   'location_longitude': -97.674176,
#   'location_name': ' BRAKER LN / JOSEPH CLAYTON DR',
#   'primary_st': ' BRAKER LN',
#   'primary_st_block': '800',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2017',
#   'request_id': 'REQ17-002545',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 979,
#   'atd_eval_id': 'PVL17-001770',
#   'cross_st': ' SAN JACINTO BLVD',
#   'cross_st_block': '1300',
#   'eval_rank': '123',
#   'eval_score': '215',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'PHB',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.274358,
#   'location_longitude': -97.7378129,
#   'location_name': ' 13TH ST / SAN JACINTO BLVD',
#   'primary_st': ' 13TH ST',
#   'primary_st_block': '200',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2017',
#   'request_id': 'REQ17-002540',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 980,
#   'atd_eval_id': 'PVL17-001765',
#   'cross_st': ' BANYON ST',
#   'cross_st_block': '801',
#   'eval_rank': '41',
#   'eval_score': '414',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'PHB',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.3423666,
#   'location_longitude': -97.715959,
#   'location_name': ' LAMAR BLVD / BANYON ST',
#   'primary_st': ' LAMAR BLVD',
#   'primary_st_block': '7500',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2017',
#   'request_id': 'REQ14-002915',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 981,
#   'atd_eval_id': 'PVL17-001760',
#   'cross_st': ' WEST AVE',
#   'cross_st_block': '1800',
#   'eval_rank': '38',
#   'eval_score': '415',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'PHB',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.28289,
#   'location_longitude': -97.745935,
#   'location_name': ' MARTIN LUTHER KING JR BLVD / WEST AVE',
#   'primary_st': ' MARTIN LUTHER KING JR BLVD',
#   'primary_st_block': '706',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2017',
#   'request_id': 'REQ17-002530',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 982,
#   'atd_eval_id': 'PVL17-001755',
#   'cross_st': ' SAGEBRUSH TRL',
#   'cross_st_block': '4601',
#   'eval_rank': '105',
#   'eval_score': '290',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'PHB',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.229099,
#   'location_longitude': -97.799564,
#   'location_name': ' WESTERN TRAILS BLVD / SAGEBRUSH TRL',
#   'primary_st': ' WESTERN TRAILS BLVD',
#   'primary_st_block': '2600',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2017',
#   'request_id': 'REQ17-002520',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 983,
#   'atd_eval_id': 'PVL17-001750',
#   'cross_st': ' BERKMAN DR',
#   'cross_st_block': '4800',
#   'eval_rank': '105',
#   'eval_score': '290',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'PHB',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.301258,
#   'location_longitude': -97.700294,
#   'location_name': ' BERKMAN DR / BERKMAN DR',
#   'primary_st': ' BERKMAN DR',
#   'primary_st_block': '4800',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2017',
#   'request_id': 'REQ17-002500',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 984,
#   'atd_eval_id': 'PVL17-001745',
#   'cross_st': ' WOODVIEW AVE',
#   'cross_st_block': '5700',
#   'eval_rank': '101',
#   'eval_score': '310',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'PHB',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.335427,
#   'location_longitude': -97.743919,
#   'location_name': ' ALLANDALE RD / WOODVIEW AVE',
#   'primary_st': ' ALLANDALE RD',
#   'primary_st_block': '2400',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2017',
#   'request_id': 'REQ17-002475',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 985,
#   'atd_eval_id': 'PVL17-001740',
#   'cross_st': ' ROCKRIDGE DR',
#   'cross_st_block': '2522',
#   'eval_rank': '38',
#   'eval_score': '415',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'PHB',
#   'funding_status': '2016 Bond Corridor',
#   'location_latitude': 30.182987,
#   'location_longitude': -97.75351,
#   'location_name': ' WILLIAM CANNON DR / ROCKRIDGE DR',
#   'primary_st': ' WILLIAM CANNON DR',
#   'primary_st_block': '4401',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2017',
#   'request_id': 'REQ17-002880',
#   'request_status': 'STUDY'},
#  {'id': 986,
#   'atd_eval_id': 'PVL17-001735',
#   'cross_st': ' LAFAYETTE AVE',
#   'cross_st_block': '3700',
#   'eval_rank': '',
#   'eval_score': '385',
#   'eval_status': 'COMPLETED',
#   'eval_type': 'PHB',
#   'funding_status': '1/4 Cent',
#   'location_latitude': 30.293259,
#   'location_longitude': -97.7164239,
#   'location_name': ' 38TH HALF ST / LAFAYETTE AVE',
#   'primary_st': ' 38TH HALF ST',
#   'primary_st_block': '1300',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2017',
#   'request_id': 'REQ14-002935',
#   'request_status': 'CONSTRUCTED'},
#  {'id': 987,
#   'atd_eval_id': 'PVL17-001725',
#   'cross_st': ' 1ST ST',
#   'cross_st_block': '9500',
#   'eval_rank': '32',
#   'eval_score': '420',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'PHB',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.167207,
#   'location_longitude': -97.801341,
#   'location_name': ' 1ST ST / 1ST ST (Mary Moore Searight off leash trail)',
#   'primary_st': ' 1ST ST',
#   'primary_st_block': '9400',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2017',
#   'request_id': 'REQ17-002390',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 988,
#   'atd_eval_id': 'PVL17-001720',
#   'cross_st': ' ROGGE LN',
#   'cross_st_block': '1700',
#   'eval_rank': '',
#   'eval_score': '0',
#   'eval_status': 'COMPLETED',
#   'eval_type': 'PHB',
#   'funding_status': 'Bond - SRTS',
#   'location_latitude': 30.3077316,
#   'location_longitude': -97.6964722,
#   'location_name': ' BERKMAN DR / ROGGE LN',
#   'primary_st': ' BERKMAN DR',
#   'primary_st_block': '5400',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2017',
#   'request_id': 'REQ14-002900',
#   'request_status': 'RECOMMENDED'},
#  {'id': 989,
#   'atd_eval_id': 'PVL17-001710',
#   'cross_st': '  ',
#   'cross_st_block': '0',
#   'eval_rank': '',
#   'eval_score': '550',
#   'eval_status': 'COMPLETED',
#   'eval_type': 'PHB',
#   'funding_status': '2016 Bond Corridor',
#   'location_latitude': 30.370964,
#   'location_longitude': -97.726965,
#   'location_name': '8700 BLK BURNET RD (South of US183)',
#   'primary_st': ' BURNET RD',
#   'primary_st_block': '8700',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2016',
#   'request_id': 'REQ17-002380',
#   'request_status': 'STUDY'},
#  {'id': 990,
#   'atd_eval_id': 'PVL16-001705',
#   'cross_st': ' RAMSEY AVE',
#   'cross_st_block': '4500',
#   'eval_rank': '100',
#   'eval_score': '220',
#   'eval_status': 'COMPLETED',
#   'eval_type': 'PHB',
#   'funding_status': '1/4 Cent',
#   'location_latitude': 30.3162044,
#   'location_longitude': -97.7433696,
#   'location_name': ' 45TH ST / RAMSEY AVE',
#   'primary_st': ' 45TH ST',
#   'primary_st_block': '1600',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2016',
#   'request_id': 'REQ14-001485',
#   'request_status': 'RECOMMENDED'},
#  {'id': 991,
#   'atd_eval_id': 'PVL16-001695',
#   'cross_st': ' TWIN OAKS DR',
#   'cross_st_block': '2401',
#   'eval_rank': '',
#   'eval_score': '422',
#   'eval_status': 'COMPLETED',
#   'eval_type': 'PHB',
#   'funding_status': '2016 Bond Corridor',
#   'location_latitude': 30.3419999,
#   'location_longitude': -97.7386757,
#   'location_name': ' BURNET RD / TWIN OAKS DR',
#   'primary_st': ' BURNET RD',
#   'primary_st_block': '6600',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2016',
#   'request_id': 'REQ14-002025',
#   'request_status': 'STUDY'},
#  {'id': 992,
#   'atd_eval_id': 'PVL16-001690',
#   'cross_st': ' PENNY LN',
#   'cross_st_block': '2401',
#   'eval_rank': '',
#   'eval_score': '529',
#   'eval_status': 'COMPLETED',
#   'eval_type': 'PHB',
#   'funding_status': '2016 Bond Corridor',
#   'location_latitude': 30.3644978,
#   'location_longitude': -97.7286359,
#   'location_name': ' BURNET RD / PENNY LN',
#   'primary_st': ' BURNET RD',
#   'primary_st_block': '8400',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2016',
#   'request_id': 'REQ13-001900',
#   'request_status': 'STUDY'},
#  {'id': 993,
#   'atd_eval_id': 'PVL16-001685',
#   'cross_st': ' ASHDALE DR',
#   'cross_st_block': '2401',
#   'eval_rank': '',
#   'eval_score': '688',
#   'eval_status': 'IN PROGRESS',
#   'eval_type': 'PHB',
#   'funding_status': 'TAP Grant',
#   'location_latitude': 30.3585956,
#   'location_longitude': -97.7301715,
#   'location_name': ' BURNET RD / ASHDALE DR',
#   'primary_st': ' BURNET RD',
#   'primary_st_block': '8004',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2016',
#   'request_id': 'REQ15-002030',
#   'request_status': 'TURNED_ON'},
#  {'id': 994,
#   'atd_eval_id': 'PVL16-001680',
#   'cross_st': ' JACOB FONTAINE LN',
#   'cross_st_block': '501',
#   'eval_rank': '',
#   'eval_score': '345',
#   'eval_status': 'COMPLETED',
#   'eval_type': 'PHB',
#   'funding_status': '2016 Bond Corridor',
#   'location_latitude': 30.325404,
#   'location_longitude': -97.716012,
#   'location_name': ' AIRPORT BLVD / JACOB FONTAINE LN (Highland Mall Entry Plaza)',
#   'primary_st': ' AIRPORT BLVD',
#   'primary_st_block': '5900',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2016',
#   'request_id': 'REQ16-002075',
#   'request_status': 'STUDY'},
#  {'id': 995,
#   'atd_eval_id': 'PVL16-001675',
#   'cross_st': ' 46TH ST',
#   'cross_st_block': '920',
#   'eval_rank': '',
#   'eval_score': '434',
#   'eval_status': 'COMPLETED',
#   'eval_type': 'PHB',
#   'funding_status': '2016 Bond Corridor',
#   'location_latitude': 30.3048494,
#   'location_longitude': -97.7159389,
#   'location_name': ' AIRPORT BLVD / 46TH ST',
#   'primary_st': ' AIRPORT BLVD',
#   'primary_st_block': '4600',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2016',
#   'request_id': 'REQ14-001980',
#   'request_status': 'STUDY'},
#  {'id': 996,
#   'atd_eval_id': 'PVL16-001670',
#   'cross_st': ' 40TH ST',
#   'cross_st_block': '1816',
#   'eval_rank': '',
#   'eval_score': '335',
#   'eval_status': 'COMPLETED',
#   'eval_type': 'PHB',
#   'funding_status': '2016 Bond Corridor',
#   'location_latitude': 30.2915163,
#   'location_longitude': -97.7076717,
#   'location_name': ' AIRPORT BLVD / 40TH ST',
#   'primary_st': ' AIRPORT BLVD',
#   'primary_st_block': '4000',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2016',
#   'request_id': 'REQ16-002080',
#   'request_status': 'STUDY'},
#  {'id': 997,
#   'atd_eval_id': 'PVL16-001665',
#   'cross_st': ' 46TH ST',
#   'cross_st_block': '521',
#   'eval_rank': '',
#   'eval_score': '451',
#   'eval_status': 'COMPLETED',
#   'eval_type': 'PHB',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.313028,
#   'location_longitude': -97.73252,
#   'location_name': ' GUADALUPE ST / 46TH ST',
#   'primary_st': ' GUADALUPE ST',
#   'primary_st_block': '4526',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2016',
#   'request_id': 'REQ16-002170',
#   'request_status': 'STUDY'},
#  {'id': 998,
#   'atd_eval_id': 'PVL16-001660',
#   'cross_st': ' PARKWOOD RD',
#   'cross_st_block': '4400',
#   'eval_rank': '',
#   'eval_score': '407',
#   'eval_status': 'COMPLETED',
#   'eval_type': 'PHB',
#   'funding_status': '2016 Bond Corridor',
#   'location_latitude': 30.3004634,
#   'location_longitude': -97.7127191,
#   'location_name': ' AIRPORT BLVD / PARKWOOD RD',
#   'primary_st': ' AIRPORT BLVD',
#   'primary_st_block': '4401',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2016',
#   'request_id': 'REQ14-002940',
#   'request_status': 'STUDY'},
#  {'id': 999,
#   'atd_eval_id': 'PVL16-001655',
#   'cross_st': ' DIME CIR',
#   'cross_st_block': '3719',
#   'eval_rank': '',
#   'eval_score': '450',
#   'eval_status': 'COMPLETED',
#   'eval_type': 'PHB',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.2033142,
#   'location_longitude': -97.71224,
#   'location_name': ' BURLESON RD / DIME CIR',
#   'primary_st': ' BURLESON RD',
#   'primary_st_block': '6500',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2016',
#   'request_id': 'REQ13-002155',
#   'request_status': 'UNDER EVALUATION'},
#  {'id': 1000,
#   'atd_eval_id': 'PVL16-001650',
#   'cross_st': ' 40TH ST',
#   'cross_st_block': '900',
#   'eval_rank': '61',
#   'eval_score': '364',
#   'eval_status': 'COMPLETED',
#   'eval_type': 'PHB',
#   'funding_status': 'None Identified',
#   'location_latitude': 30.298572,
#   'location_longitude': -97.7226818,
#   'location_name': ' RED RIVER ST / 40TH ST',
#   'primary_st': ' RED RIVER ST',
#   'primary_st_block': '4000',
#   'rank_round_mo': 'DEC',
#   'rank_round_yr': '2016',
#   'request_id': 'REQ14-001595',
#   'request_status': 'STUDY'},
#  ...]
